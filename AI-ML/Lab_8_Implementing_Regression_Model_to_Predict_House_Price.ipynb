# %% [markdown]
# # Lab 8 - Training a Regression Model to Predict House Price using Boston Housing Dataset
# **Date:** 22 November 2023
#
#
# **Problem Statement**: Build and Train a Neural Network based Regression Model to predict the median price of houses in a given Boston suburb. Use The Boston Housing Price dataset for the purpose. The dataset contains house prices for houses from Boston suburb in the 1970s. Since the dataset size is relatively very less, use K-fold cross validation during the training phase. Apply appropriate feature scaling before inputting the data to the model. Finally evaluate the model on Test data and use the resulting trained and evaluated model to do the predictions on some data.

# %% [markdown]
# # Step 1 - Data Exploration and Pre-processing

# %%
from keras.datasets import boston_housing

(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
# Have a look at the data
train_data.shape
# Out:
# (404, 13)

# %%
test_data.shape
# Out:
# (102, 13)

# %%
train_targets # The housing price is given in thousands of dollars
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
# ...

# %% [markdown]
# The Boston Housing dataset has 13 numerical features such as per capita crime rate, avg no of rooms, etc. Each feature has different range. For instance avg_no_of_rooms may vary from 2 to 10 whereas crime_rate_per_capita might vary between 0 and 100. It would be problematic to feed a neural network values which are of different scales. Thus we should first normalize each feature so that it falls within the same range, say between 0 and 1.

# %%
# Feature Scaling or Normalizing the data
# (x - mean(x))/std(x) -- after this data falls between -1 and 1 with mean as 0

mean = train_data.mean(axis=0)
train_data -= mean

std = train_data.std(axis=0)
train_data /= std

test_data -= mean # use the means of the training data itself
test_data /= std # use the standard deviations of the training data itself

# %% [markdown]
# # Step 2 - Build your network
#
# Since we have less data we should build a relatively small model, say only with two hidden layers with 64 units per layer.

# %%
from keras import models
from keras import layers

def build_model():
  model = models.Sequential()
  model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1)) # no activation used, it will be a linear layer
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %% [markdown]
# # Step 3 - Validating the model using K-fold cross validation
#
# If we use a single fold cross validation, we will have to split training data into a training set and a validation set. But because we have very few datapoints (only 404), the validation set will have too less data points (may be less than 100). Thus, validation scores can be misleading varying with each sample you chose for training and validation.
#
# The best practice in such case is to use K-fold cross validation and then use the avergage validation of the k iterations. This is more reliable.![3-Fold Cross Validation.png](data:image/png;base64,...)

# %%
# Implement k-Fold Cross Validation
import numpy as np

k = 5
num_val_samples = len(train_data) // k
num_epochs = 100
all_scores = []
for i in range(k) :
  print(f"Processing fold #{i}")
  val_data = train_data[i * num_val_samples : (i + 1) * num_val_samples]
  val_targets = train_targets[i * num_val_samples : (i + 1) * num_val_samples]
  partial_train_data = np.concatenate(
            [train_data[:i * num_val_samples],
             train_data[(i+1) * num_val_samples:]],
            axis=0)
  partial_train_targets = np.concatenate(
            [train_targets[:i * num_val_samples],
             train_targets[(i+1) * num_val_samples:]],
            axis=0)
  model = build_model()
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs,
            batch_size=16, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores.append(val_mae)
# Out:
# Processing fold #0
# Processing fold #1
# Processing fold #2
# Processing fold #3
# Processing fold #4
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7ab1c5fa30a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
all_scores
# Out:
# [1.9636116027832031,
#  2.7269434928894043,
#  2.414691209793091,
#  2.559147596359253,
#  2.357287883758545]

# %%
np.mean(all_scores)
# Out:
# 2.404336357116699

# %% [markdown]
# **Increasing the number of epochs and capturing and saving the per epoch validation scores for each fold**
#
# We will try to train the network a bit longer: for 500 epochs. To keep a record of how well the model does at each epoch, we will modify the training loop to save the per epoch validation score log

# %%
num_epochs = 500
all_mae_history = []
for i in range(k) :
  print(f"Processing fold #{i}")
  val_data = train_data[i * num_val_samples : (i + 1) * num_val_samples]
  val_targets = train_targets[i * num_val_samples : (i + 1) * num_val_samples]
  partial_train_data = np.concatenate(
            [train_data[:i * num_val_samples],
             train_data[(i+1) * num_val_samples:]],
            axis=0)
  partial_train_targets = np.concatenate(
            [train_targets[:i * num_val_samples],
             train_targets[(i+1) * num_val_samples:]],
            axis=0)
  model = build_model()
  history = model.fit(partial_train_data, partial_train_targets,
                      validation_data=(val_data, val_targets),
                      epochs=num_epochs, batch_size=16, verbose=0)
  mae_history = history.history["val_mae"]
  all_mae_history.append(mae_history)
# Out:
# Processing fold #0
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7ab1c52f5e10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Processing fold #1
# Processing fold #2
# Processing fold #3
# Processing fold #4

# %% [markdown]
# **Calculating the average of per epoch MAE score**
# We will build a history of successive mean K-fold validation scores per epoch.

# %%
average_mae_history = [
            np.mean([x[i] for x in all_mae_history]) for i in range(num_epochs)]

# %% [markdown]
# **Plotting the average mae validation scores per epoch**

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
# Out:
# Text(0, 0.5, 'Validation MAE')

# %% [markdown]
# **Plotting validation scores after excluding the first 10 data points**
# It is difficult to see the above plot due to scaling issues and high variance. The first 10 data points are on a different scale from the rest of the data points on the curve. So we omit those and then plot again.

# %%
truncated_mae_history = average_mae_history[10:]
plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
# Out:
# Text(0, 0.5, 'Validation MAE')

# %% [markdown]
# #Step 4: Training the final model from scratch with all the original training data

# %%
model = build_model()
model.fit(train_data, train_targets, epochs=150, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 12.9918 - mae: 2.3584

# %%
test_mae_score
# Out:
# 2.358377695083618

# %% [markdown]
# # Step 5: Generating predictions on new data

# %%
predictions = model.predict(test_data)
predictions[0]
# Out:
# 4/4 [==============================] - 0s 4ms/step
# array([7.7290077], dtype=float32)

# %%
test_targets[0]
# Out:
# 7.2
